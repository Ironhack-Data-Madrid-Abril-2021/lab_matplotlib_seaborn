# %% [markdown]
# ## Before you start :
#    - These exercises are related to the Exploratory data analysis using matplotlib and seaborn.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - The datasets for Challenge 2 and 3 are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# import libraries here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pylab as plt
# %matplotlib inline

# %% [markdown]
# #### Define data.

# %%
x = np.arange(0,100)
y = x*2
z = x**2

df = pd.DataFrame(x, columns=list('x'))
df['y'] = x*2
df['z'] =  x**2

# %% [markdown]
# #### Plot (x,y) and (x,z) on the axes.
#
# #### There are 2 ways of doing this. Do in both ways.
#
# *Hint: Check out the `nrows`, `ncols`, and `index` arguments of [subplots](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplot.html)*
#
# #### Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# your code here-1st way (call `subplots` twice using the `index` parameter)
plt.subplot(1,2,1) #(1 fila, 2 colunas, 1º elemento -> indicar o elemento afectado)
plt.plot(x,y, linewidth=2.0, color='r') #(plot x, y , sendo que y = 2x.)
plt.title('y=2·x',size=12,fontweight='bold') #title, formatações
plt.subplot(1,2,2) #(1 fila, 2 colunas, 2º elemento -> indicar o elemento afectado)
plt.plot(x,z, linewidth=5.0, color='y') #(plot x, z , sendo que z = x^2)
plt.title('z=x^2',size=12,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'z=x^2')

# %%
# your code here-2st way (call `subplots` only once not using the `index` parameter)
for i in range(2): # dois gráficos
    if i==0: # primeiro gráfico
        f=y # f(x) = y = 2x
        title='y=2·x' # título
        linewidth=2.0 # formato
        color='r' # formato
    else:
        f=z # f(x) = z = x^2
        title='z=x^2' # título
        linewidth=5.0 # formato
        color='y'# formato
    plt.subplot(1,2,i+1)
    plt.plot(x,f, linewidth=linewidth, color=color)
    plt.title(title,size=12,fontweight='bold')

# %%
# There would be another way to do this (though not answering as required):
plt.plot(x,y)
plt.plot(x,z);

# %% [markdown]
# #### Augmenting your previous code, resize your previous plot.
#
# *Hint: Add the `figsize` argument in `plt.subplots()`*

# %%
# your code here
plt.rcParams['figure.figsize']=(15, 8)
plt.subplot(1,2,1)
plt.plot(x,y, linewidth=2.0, color='r')
plt.title('y=2·x',size=12,fontweight='bold')
plt.subplot(1,2,2) 
plt.plot(x,z, linewidth=5.0, color='y')
plt.title('z=x^2',size=12,fontweight='bold');

# %% [markdown]
# plt.rcParams['figure.figsize']=(15, 8)
# fig, axs = plt.subplots(1,2)
# fig.suptitle('Graphs')
# axs[0].plot(x, y)
# axs[1].plot(x, z);

# %% [markdown]
# #### Augmenting your previous code, label your axes.
#
# *Hint: call `set_xlabel` and `set_ylabel`*

# %%
# your code here
plt.rcParams['figure.figsize']=(15, 8)
fig.suptitle('Graphs')
fig, ax = plt.subplots(1 , 2)
ax[0].plot(x,y, linewidth=2.0, color='r')
ax[0].set_title('y = 2x',size=12,fontweight='bold')
ax[0].set_xlabel('x-label')
ax[0].set_ylabel('y-label')
ax[1].plot(x,z, linewidth=5.0, color='y')
ax[1].set_title('z = x^2',size=12,fontweight='bold')
ax[1].set_xlabel('x-label')
ax[1].set_ylabel('z-label');

# %% [markdown]
# #### Plot both `y=x^2` and `y=exp(x)` in the same plot using normal and logarithmic scale.
#
# *Hint: Use `set_xscale` and `set_yscale`*

# %%
#your code here

w = np.exp(x)

plt.rcParams['figure.figsize']=(15, 8)
fig.suptitle('Graphs')
fig, ax = plt.subplots(1 , 3)
ax[0].plot(x,y, linewidth=2.0, color='r')
ax[0].set_title('y = 2x',size=12,fontweight='bold')
ax[0].set_xlabel('x-label')
ax[0].set_ylabel('y-label')
ax[1].plot(x,z, linewidth=5.0, color='y')
ax[1].set_title('z = x^2',size=12,fontweight='bold')
ax[1].set_xlabel('x-label')
ax[1].set_ylabel('z-label')
ax[2].plot(x,w, linewidth=5.0, color='b')
ax[2].set_title('w = e^x',size=12,fontweight='bold')
ax[2].set_xlabel('x-label')
ax[2].set_yscale('log')
ax[2].set_ylabel('w-label')
ax[2].plot(x,z, linewidth=5.0, color='y');

# %% [markdown]
# #### In the vehicles data set that you have downloaded, use the vehicles.csv file. In this exercise we will conduct some exploratory data analysis using one plot each of scatter plot, box plot, histogram, and bar chart.

# %% [markdown]
# Scatter Plot
#
# Please provide a scatter plot between "Combined MPG" as X variable and
# "Highway MPG" as Y variable

# %%
# your code here
vh = pd.read_csv('vehicles.csv')
display(vh.head())
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
vh.columns
# Out:
# Index(['make', 'model', 'year', 'engine_displacement', 'cylinders',
#        'transmission', 'drivetrain', 'vehicle_class', 'fuel_type',
#        'fuel_barrels_year', 'city_mpg', 'highway_mpg', 'combined_mpg',
#        'co2_emission_grams_mile', 'fuel_cost_year'],
#       dtype='object')

# %%
vh.columns = [c.lower().replace(' ','_').replace('/','_') for c in vh.columns]

# %% [markdown]
# Box Whisker Plot
#
# Please provide a box plot of the variable "CO2 Emission Grams/mile"

# %%
# your code here
sns.boxplot(x=vh.co2_emission_grams_mile, color='b');

# %% [markdown]
# Histogram
#
# Please provide a histogram of the Fuel Barrels/Year

# %%
# your code here

sns.histplot(x=vh.fuel_type, color='black')
# Out:
# <AxesSubplot:xlabel='fuel_type', ylabel='Count'>

# %% [markdown]
# Bar Chart
#
# Please provide a bar chart of the Fuel Type on the X axis and "City MPG" on the Y axis

# %%
# your code here
ax=vh.groupby('fuel_type').sum().city_mpg.plot(kind='bar', color=['black', 'b'], grid=True, figsize=(12, 8), title='Fuel type vs City MPG')

ax.set_xlabel('Fuel Type')
ax.set_ylabel('City MPG')

plt.show();
